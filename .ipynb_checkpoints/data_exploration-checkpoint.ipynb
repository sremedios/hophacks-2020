# %%
import nibabel as nib
import matplotlib.pyplot as plt
import tqdm
import os
import sys
from pathlib import Path

from utils.plot import *

# %%
CT_DIR = Path("D:\data\covid\MosMedData Chest CT Scans with COVID-19 Related Findings COVID19_1110 1.0\studies\CT-1")
MASK_DIR = Path("D:\data\covid\MosMedData Chest CT Scans with COVID-19 Related Findings COVID19_1110 1.0\masks")

# %%
ct_obj = nib.load(ct_file)
zooms = ct_obj.header.get_zooms()

# %%
zooms
# Out:
# (0.782, 0.782, 8.0)

# %%
k = max(zooms) / min(zooms)

# %%
k
# Out:
# 10.230179

# %%
ct_obj.shape
# Out:
# (512, 512, 41)

# %%
int(np.ceil(min(ct_obj.shape) * k))
# Out:
# 420

# %%
target_shape = (*ct_obj.shape[:-1], int(np.ceil(min(ct_obj.shape) * k)))

# %%
target_shape
# Out:
# (512, 512, 420)

# %%
for ct_file, mask_file in zip(CT_DIR.iterdir(), MASK_DIR.iterdir()):
    ct_obj = nib.load(ct_file)
    zooms = ct_obj.header.get_zooms()
    k = max(zooms) / min(zooms)
    target_shape = (*ct_obj.shape[:-1], int(np.ceil(min(ct_obj.shape) * k)))
    ct = ct_obj.get_fdata()
    
    
    mask = nib.load(mask_file).get_fdata()
    
    
    
    center_vol_plot(ct, target_shape)
    center_vol_plot(mask, target_shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-10efcd3bec90> in <module>
#      11
#      12
# ---> 13     center_vol_plot(ct, target_shape)
#      14     center_vol_plot(mask, target_shape)
#
# ~\hophacks-2020\utils\plot.py in center_vol_plot(img_vol, target_shape)
#      56         [x, y, z],
#      57         ['Axial','Sagittal','Coronal'],
# ---> 58     )
#
# ~\hophacks-2020\utils\plot.py in multiplot(imgs, titles, vmin, vmax)
#      26
#      27     plt.show()
# ---> 28
#      29 def center_vol_plot(img_vol, target_shape=None):
#      30
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2052                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2053                             bbox_extra_artists=bbox_artists)
#    2054                     pad = kwargs.pop("pad_inches", None)
#    2055                     if pad is None:
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2268
#    2269         for a in artists:
# -> 2270             bbox = a.get_tightbbox(renderer)
#    2271             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2272                 bb.append(bbox)
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4394
#    4395         for a in bbox_artists:
# -> 4396             bbox = a.get_tightbbox(renderer)
#    4397             if (bbox is not None and
#    4398                     (bbox.width != 0 or bbox.height != 0) and
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\artist.py in get_tightbbox(self, renderer)
#     269         """
#     270
# --> 271         bbox = self.get_window_extent(renderer)
#     272         if self.get_clip_on():
#     273             clip_box = self.get_clip_box()
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\spines.py in get_window_extent(self, renderer)
#     151         # correct:
#     152         self._adjust_location()
# --> 153         return super().get_window_extent(renderer=renderer)
#     154
#     155     def get_path(self):
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\patches.py in get_window_extent(self, renderer)
#     546
#     547     def get_window_extent(self, renderer=None):
# --> 548         return self.get_path().get_extents(self.get_transform())
#     549
#     550
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\path.py in get_extents(self, transform)
#     526         path = self
#     527         if transform is not None:
# --> 528             transform = transform.frozen()
#     529             if not transform.is_affine:
#     530                 path = self.transformed(transform)
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    2191
#    2192     def frozen(self):
# -> 2193         return blended_transform_factory(self._x.frozen(), self._y.frozen())
#    2194     frozen.__doc__ = Transform.frozen.__doc__
#    2195
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    2377     def frozen(self):
#    2378         self._invalid = 0
# -> 2379         frozen = composite_transform_factory(self._a.frozen(), self._b.frozen())
#    2380         if not isinstance(frozen, CompositeGenericTransform):
#    2381             return frozen.frozen()
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    2379         frozen = composite_transform_factory(self._a.frozen(), self._b.frozen())
#    2380         if not isinstance(frozen, CompositeGenericTransform):
# -> 2381             return frozen.frozen()
#    2382         return frozen
#    2383     frozen.__doc__ = Transform.frozen.__doc__
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    1797
#    1798     def frozen(self):
# -> 1799         return Affine2D(self.get_matrix().copy())
#    1800     frozen.__doc__ = AffineBase.frozen.__doc__
#    1801
#
# c:\users\sam\anaconda3\envs\ot-flow\lib\site-packages\matplotlib\transforms.py in get_matrix(self)
#    2527             self._mtx = np.dot(
#    2528                 self._b.get_matrix(),
# -> 2529                 self._a.get_matrix())
#    2530             self._inverted = None
#    2531             self._invalid = 0
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
